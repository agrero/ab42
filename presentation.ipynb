# %%
import plotly.io as pio

from slide_types.SingleColumnSlide import SingleColumnSlide
from slide_types.content.PlotlyContent import PlotlyContent
from slide_types.content.TextContent import TextContent

# %%
intro = SingleColumnSlide(
    title="Something Declarative About the Results ",
    content_block=TextContent(
        text="""
    <b>An Investigation into the Sequence Permuations of beta-Amyloid-42</b>
    By: Alex Guerrero
    """
    )
)

# %%
motif_sum_v1_intro_slide = SingleColumnSlide(
    title="Motif Sum Plots V1",
    content_block=TextContent(
        text="""
        <b>Each bar is colored by its motif and ordered by greatest to lowest</b>
        """
    )
)

motif_sum_3_plot = pio.read_json("plots/motiflen_3.json")
motifsum_3_slide = SingleColumnSlide(
    title="",
    content_block=PlotlyContent(
        fig=motif_sum_3_plot
    )
)

motif_sum_6_plot = pio.read_json("plots/motiflen_6.json")
motif_sum_6_slide = SingleColumnSlide(
    title="",
    content_block=PlotlyContent(
        fig=motif_sum_6_plot
    )
)
motif_sum_9_plot = pio.read_json("plots/motiflen_9.json")
motif_sum_9_slide = SingleColumnSlide(
    title="",
    content_block=PlotlyContent(
        fig=motif_sum_9_plot
    )
)

# %%
motif_sum_v2_intro_slide = SingleColumnSlide(
    title="Motif Sum Plots V2",
    content_block=TextContent(
        text="<b>Each bar is colored by its Secondary Structure Type, and the ordering does not change</b>"
    )
)
motif_sum_3_v2_plot = pio.read_json("plots/motiflen_3_v2.json")
motif_sum_3_v2_slide = SingleColumnSlide(
    title="",
    content_block=PlotlyContent(
        fig = motif_sum_3_v2_plot
    )
)

# %%
intro.display()
# Out:
# <div style="font-family: Arial, sans-serif; font-size: 16px; color: #222222; padding: 20px; line-height: 1.6;">
#     <h1 style="font-size: 2.5rem; color: #007acc; margin-bottom: 25px; text-align: left; font-weight: 700;">
#         Something Declarative About the Results
#     </h1>
#
#     <div style="width: 100%; text-align: left;">
#         <div class="slide-text"><b>An Investigation into the Sequence Permuations of beta-Amyloid-42</b><br>By: Alex Guerrero</div>
#     </div>
# </div>
#
# <style>
#     .slide-text h3, .slide-text b, .slide-text strong {
#         font-size: 1.5rem;
#         color: #222222;
#         display: inline-block;
#         margin-bottom: 8px;
#     }
# </style>

# %%
motif_sum_v1_intro_slide.display()
# Out:
# <div style="font-family: Arial, sans-serif; font-size: 16px; color: #222222; padding: 20px; line-height: 1.6;">
#     <h1 style="font-size: 2.5rem; color: #007acc; margin-bottom: 25px; text-align: left; font-weight: 700;">
#         Motif Sum Plots V1
#     </h1>
#
#     <div style="width: 100%; text-align: left;">
#         <div class="slide-text"><b>Each bar is colored by its motif and ordered by greatest to lowest</b></div>
#     </div>
# </div>
#
# <style>
#     .slide-text h3, .slide-text b, .slide-text strong {
#         font-size: 1.5rem;
#         color: #222222;
#         display: inline-block;
#         margin-bottom: 8px;
#     }
# </style>

# %%
motifsum_3_slide.display()
# Out:
# <div style="font-family: Arial, sans-serif; font-size: 16px; color: #222222; padding: 20px; line-height: 1.6;">
#     <h1 style="font-size: 2.5rem; color: #007acc; margin-bottom: 25px; text-align: left; font-weight: 700;">
#
#     </h1>
#
#     <div style="width: 100%; text-align: left;">
#         <div style="height:100%; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# motif_sum_6_slide.display()

# %%
# motif_sum_9_slide.display()

# %%
motif_sum_v2_intro_slide.display()
# Out:
# <div style="font-family: Arial, sans-serif; font-size: 16px; color: #222222; padding: 20px; line-height: 1.6;">
#     <h1 style="font-size: 2.5rem; color: #007acc; margin-bottom: 25px; text-align: left; font-weight: 700;">
#         Motif Sum Plots V2
#     </h1>
#
#     <div style="width: 100%; text-align: left;">
#         <div class="slide-text"><b>Each bar is colored by its Secondary Structure Type, and the ordering does not change</b></div>
#     </div>
# </div>
#
# <style>
#     .slide-text h3, .slide-text b, .slide-text strong {
#         font-size: 1.5rem;
#         color: #222222;
#         display: inline-block;
#         margin-bottom: 8px;
#     }
# </style>

# %%
motif_sum_3_v2_slide.display()
# Out:
# <div style="font-family: Arial, sans-serif; font-size: 16px; color: #222222; padding: 20px; line-height: 1.6;">
#     <h1 style="font-size: 2.5rem; color: #007acc; margin-bottom: 25px; text-align: left; font-weight: 700;">
#
#     </h1>
#
#     <div style="width: 100%; text-align: left;">
#         <div style="height:100%; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
